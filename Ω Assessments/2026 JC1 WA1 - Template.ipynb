# %% [markdown]
# # 2026 JC1 Weighted Assessment WA1

# %%
## DO NOT MODIFY this cell. Run it to enter your name and class. ##

name = input('Enter your full name: ')
cg = input('Enter your CG: ')

# %% [markdown]
# # Task 1.1

# %%
string = 'Andy Teo (15-05) John Lim'

# Write your code below this line
openbracket = string.index('(')
closebracket = string.index(')')
dash = string.index('-')
score1 = string[openbracket+1:dash]
score2 = string[dash+1:closebracket]

if score1 > score2:
    print(score1)
else:
    print(score2)
# Out:
# 15
# 05

# %% [markdown]
# # Task 1.2

# %%
string = 'Andy Teo (15-05) John Lim'

# Copy your code from Task 1.1 below this line and make modifications
openbracket = string.index('(')
closebracket = string.index(')')
dash = string.index('-')
score1 = string[openbracket+1:dash]
score2 = string[dash+1:closebracket]
player1 = string[:openbracket-1]
player2 = string[closebracket+1:]
if score1 > score2:
    print(player1 + ": "+ score1)
else:
    print(player2 + ": "+ score2)
# Out:
#  John Lim: 55

# %% [markdown]
# # Task 2.1 User Input with Validation [6 marks]

# %%
length = 35.0
width = 25.0
                                                              
def main():
    height = input('Please enter the height of your parcel: ')
    if height.isdigit():
        height = int(height)
        while not (height >= 16):
            if height.isdigit():
                height = input('Please enter the height of your parcel: ')
                height = int(height)

    print('valid')

main()
# Out:
# Please enter the height of your parcel:  2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 15
#      11                 height = int(height)
#      13     print('valid')
# ---> 15 main()
#
# Cell In[23], line 9, in main()
#       7 height = int(height)
#       8 while not (height >= 16):
# ----> 9     if height.isdigit():
#      10         height = input('Please enter the height of your parcel: ')
#      11         height = int(height)
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %% [markdown]
# # Task 2.2 Compute Delivery Charge [5 marks]

# %%
def delivery_charge(length, width, height):
    pass


print(delivery_charge(35,25,10))    
print(delivery_charge(40,30,15))    
print(delivery_charge(50,40,25))

# %% [markdown]
# # Task 3.1

# %%
def average_score(tup):
    pass

# %%
average_score(('21', '35', '51', '10', 'end', '12', '24'))

# %% [markdown]
# # Task 3.2

# %%
#copy and paste your average_score(tup) function from Task 3.1 below

def average_score(tup):
    pass

# %%
average_score(('21', '35,40,25', '51', 'end', '12', '24'))

# %% [markdown]
# # Task 4 Storing Data in a Tuple [4 marks]

# %%
def compute(results):
    pass


class123 = (('Amy', 57, 69, 52), ('Bob', 44, 45, 53), ('Charlie', 84, 72, 68))

# %% [markdown]
# # Task 5 Manipulating a List [4 marks]

# %%
def include(n):
    pass


lst = [33, 57, 76, 84, 96]

# %% [markdown]
# ~ THE END ~
