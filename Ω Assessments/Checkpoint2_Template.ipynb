# %% [markdown]
# # Checkpoint 2
# Write and test your program code using Jupyter Notebook before submitting in Coursemology.

# %% [markdown]
# # Question 1: Function with Test Cases [5 marks]

# %%
#Write program code for the function below:
#Write program code for the function below:
def convert_to_grade(score):
    if score > 100 or score < 0:
        return 'Invalid Score'
    if score >= 70:
        return 'A'
    elif score >= 60:
        return 'B'
    elif score >= 55:
        return 'C'
    elif score >=45:
        return 'D'
    elif score >= 40:
        return 'E'
    elif score >= 0:
        return 'U'
    else:
        return 'Invalid Score'


#Replace 'pass' with a value for each case:


#'Normal Data': case1 = convert_to_grade(score1)
score1 = 70

#'Extreme Data': case2 = convert_to_grade(score2)
#                case3 = convert_to_grade(score3)
score2 = 100
score3 = 0

#'Abnormal Data': case4 = convert_to_grade(score4)
#                 case5 = convert_to_grade(score5)
score4 = -1
score5 = 101

# %%
score = 30
score in [0, 100]
# Out:
# False

# %% [markdown]
# # Question 2: No. of Late Arrival [6 marks]

# %%
#Write your program code below:

# def latecoming(string):
    # length_string = len(string)
    # total_latecomings = 0
    # removals = 0
    # if length_string != 10 :
    #     return 'Invalid String'
    # for i in range(length_string):
    #     if string[i] == 'X' or string[i] == '0':
    #         print(string)
    #         string == string[i+1-removals:]
    #         print(string)
    #         removals += 1
    #     elif int(string[i])>0 or int(string[i])<=5:
    #         total_latecomings += int(string[i])
    #         print(string)
    #         string == string[i+1:]
    #         print(string)

    #         removals += 1
    #     else:
    #         return 'Invalid String'
    # return total_latecomings


#Write your program code below:
def latecoming(string):
    length = len(string)
    total = 0
    if length > 10 or length < 0:
        return 'Invalid String'
    working = string[::-1]
    for index in range(length):
        if (working[index]) == '0':
            pass
        elif working[index] == 'X':
            pass
        elif working[index].isdigit() and int(working[index])> 0 and int(working[index])<6:
            total += int(working[index])
        else:
            return 'Invalid String'
    return total


latecoming("100E010000")
# Out:
# 'Invalid String'

# %% [markdown]
# # Question 3: Password Verification [4 marks]

# %%
#Write your program code below:
def verify():
    num_tries = 0
    while True:
        password = input('Please enter a 8-character password')
        password_confirmation = input('Please enter it again for confirmation')
        tries +=1
        if password == password_confirmation:
            return 'Password reset successfully.'
        elif num_tries > 3:
            return 'Password reset failed.'
        else:
            print('try again')

# %% [markdown]
# # Question 4: Car Plate Validation (Bonus Question: 6 marks)

# %%
# Write the code for the function validate here:
def validate(carplate):
    length = len(carplate)
    middle = carplate[1:length-1]
    while True:
        if carplate[0].isalpha() == False or carplate[length-1].isalpha() == False:
            return False
        if len(middle) <=3 and len(middle)>0:
            if middle.isdigit() == True and middle.isalpha() == False:
                return True
        return False

# %%
def square_of_diff(a,b):
    return (a-b)**2
    
def sqrt_of_sum(a, b):
    return (a+b) **0.5

def distance(point1, point2):
    x1,y1 = point1
    x2,y2 = point2
    xdiff = square_of_diff(x2,x1)
    ydiff = square_of_diff(y2,y1)
    return sqrt_of_sum(xdiff,ydiff)







# Do not modify the following:
A = (0,1)
B = (3,5)

C = (1,0)
D = (6,12)

distance(A, B)
# Out:
# 625
