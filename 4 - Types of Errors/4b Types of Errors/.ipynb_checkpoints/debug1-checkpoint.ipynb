# %% [markdown]
# # Debugging Exercise 1
#
# When you code a program, you will certainly make mistakes from either simple typing mistakes and more significant conceptual bugs. Even expert programmers might produce code which contain errors. It's important to know how to find and fix errors in your code and this process is called debugging.
#
# Try running the following code:

# %%
def p1(x, y):
    return p2(x, y) + p3(x, y)

def p2(z, w):
    return z * w

def p3(a, b):
    return p2(a,a) + p2(b,b)

# %% [markdown]
# Note that the code runs with no output. The three functions have been successfully defined.
#
# Now evaluate the following expression:

# %%
p1(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 p1(1,2)
#
# Cell In[1], line 2, in p1(x, y)
#       1 def p1(x, y):
# ----> 2     return p2(x, y) + p3(x, y)
#
# Cell In[1], line 8, in p3(a, b)
#       7 def p3(a, b):
# ----> 8     return p2(a) + p2(b)
#
# TypeError: p2() missing 1 required positional argument: 'w'

# %% [markdown]
# You should encounter some error messages.
#
# Don't panic. It contains helpful information about the error that we can use to fix it. The first part of the error message is the **Traceback**. It shows a sequence of executions (the call stack) that leads to the error. By tracing through the call stack, we can easily find the source of the error.

# %% [markdown]
# ## Tracing the call stack
#
# In this example, the call stack has three layers.
#
# Running the code `p1(1,2)` leads to the error in running line 2 of the p1 function. At this point, you still do not know the actual problem.
#
# The third layer tells us that the executing of the previous line leads to the error in executing line 8.

# %% [markdown]
# ## Making sense of the error encountered
# You can see the **TypeError** in the second part of the error message which gives you the details of the error encountered.
#
# **TypeError:** p2() missing 1 required positional argument: 'w'
#
# This tells you that at this point, the interpreter ran into a type error. The description explains that p2 is missing 1 argument. When looking at the definition of p2, you will realize that it requires 2 arguments, but only one argument is passed. This is the source of the error, i.e. an argument is missing.
#
# Correct the code for line 8 by writing it as:
#
# `return p2(a,a) + p2(b,b)`
#
# Copy the amended code and submit in Coursemology.
