# %% [markdown]
# # LT 5b: Iteration: while-loop template

# %% [markdown]
# ### Question 1: while-loop

# %% [markdown]
# #### When would you use a while-loop over a for-loop?
# * 1. When there is a counter
# * 2. When I don't know how many times I want to loop
# * 3. When I am writing code to simulate eating: while I am hungry(), I take_a_bite()
# * 4. When I need to compute where to start and where to stop.

# %%
#From the four statements, there can be more than 1 correct statement. You may record your notes here.

# %% [markdown]
# ### Question 2: print to n

# %%
def print_to(n):
    number = 0
    while number <= n:
        print(number)
        number +=1

# %%
print_to(8)  #This should print to 8
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# ### Question 3: loop: break
# Test your ability to trace the code. Do not run it yet.

# %%
#Trace the code in the question, keeping track of i and result
#                   result   i
#                   ======  ===
#    Start         :   0     0  (Setup for you)
#After 1 iteration :   ?     ? 
#After 2 iterations:   ?     ?
#After 3 iterations:   ?     ?
#After 4 iterations:   ?     ?

# %% [markdown]
# ### Question 4: factorial(n): Debug the given code
# Warning: DO NOT TEST IN COURSEMOLOGY.<br>
# An infinite-loop in your code can slow down coursemology.

# %%
def factorial(n):  #Debug this function. There are more than 1 mistakes.
    i = 1
    result = 1     
    while i <= n:
        result = result * i
        i += 1
    return result

# %%
factorial(4)  #This should give 1 * 2 * 3 * 4 = 24
# Out:
# 24

# %% [markdown]
# ### Question 5: compute(x, n)

# %%
def compute(x, n):
    total = 1
    while n > 0:
        total *= x
        n -= 1
    return total

# %%
compute(2,3)   #This should return 8
# Out:
# 8

# %% [markdown]
# ### Question 6: powers_of_two(n)

# %%
def powers_of_two(n):
    power = 0
    while n != 1:
        n = n/2
        power +=1
    
    return power

# %%
powers_of_two(16) #this should give 4 since you can divide 16 by 2 4 times.
# Out:
# 4

# %% [markdown]
# ### Question 7: When will I be a millionaire?

# %%
def millionaire(amount):
    years = 0
    while amount < 1000000:
        amount = amount * 1.05
        years +=1
    return years

# %%
millionaire(555555)   #You should take 13 years to become a millionaire.
# Out:
# 13

# %% [markdown]
# ### Question 8: Sum or Subtract

# %%
def fn(n):
    total = 0
    initial = n
    evil_number_sum = 0
    n = 2
    
    while n <= initial:
        if n % 2 == 0:
            total += n
        elif n % 3 == 0:
            total += n
        else:
            evil_number_sum = evil_number_sum + n
        
        n = n + 1
    
    return total - evil_number_sum

# %%
fn(5)  #This should return 4
# Out:
# 4

# %% [markdown]
# **=====================================================================================**

# %%
# Test other code not relevant to Q1 to Q8 here

# %% [markdown]
# ### while-loop Extra Qn (Basic)
# Using a while-loop, write a function `xmas(n)` that prints a christmas tree of size n like this:

# %% [raw]
# >>> xmas(5)
# *
# **
# ***
# ****
# *****

# %%
def xmas(n):
    num = 1
    while n >0:
        print("*" * num)
        num +=1
        n-=1

# %%
xmas(5)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ### while-Loop Extra Qn (Advanced)
# Write a function `fn(x)` that repeats this logic:
#
# while the number x is not 1, keep performing these 3 instructions:
#
# -    if x is odd, multiply it by 3 and add a 1
# -    if x is even, divide it by 2
# -    print(x)

# %%
def fn(x):
    pass

# %%
fn(3)   #Expected print outputs: 10, 5, 16, 8, 4, 2, 1
