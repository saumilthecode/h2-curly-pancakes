# %% [markdown]
# # Quick Sort (in-place) Algorithm
#
# ## Description :
#
#
# - use the last element as the `pivot` to partition the array into two halves
# - the `left` half contains all the elements with values lesser than the `pivot` and the `right` half contains all the elements with values greater or equal to the `pivot`.
# - repeat to partition the `left` and `right` halves recursively until it contains only one or no element.
# - this process will result in a sorted array.

# %% [markdown]
# # Core Skill 0: Swapping 2 elements in a list
# - Temp ← Seq[1]
# - Seq[1] ← Seq[3]
# - Seq[3] ← Temp

# %%
# Core Skill 0: Swapping 2 elements in a list

seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5]

# swap elements in index 1 and 3



print(seq)

# %% [markdown]
# # Core Skill 1a: Define the variables
# - `seq`: the sequence
# - `start`: the starting index of the sequence `seq`
# - `end`: the last index in the sequence `seq`
# - `pivot`: the pivot value
# - `lo`: the left pointer, moving towards the right
# - `hi`: the right pointer, moving towards the left

# %%
# Core Skill 1a: Define variables

seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5]

start = 
end = 

pivot =                #using the last element as the pivot
lo =
hi =

# %% [markdown]
# # Core Skill 1b: Moving `Low` towards the right
#
# - `lo` starts from index 0 and moves towards the right
# - it will stop at the element with value greater or equal to the `pivot`

# %%
# Core Skill 1b: Moving `Low` towards the right

while ...

    

print(seq)
print(lo==2)         #lo will stop at index 2 since 7 is larger than the pivot 5.

# %% [markdown]
# # Core Skill 1c: Moving `High` towards the left
#
# - `hi` starts from last element and moves towards the left
# - it will stop at the element with value smaller than the `pivot`

# %%
# Core Skill 1c: Moving `High` towards the left

while ...


print(seq)
print(hi==8)         #hi will stop at index 8 since 4 is smaller than the pivot 5.

# %% [markdown]
# # Core Skill 1d: Swap the `Low` and `High` elements
#
# - the `lo` element is larger than the pivot, so it should be on the right-hand-side
# - the `hi` element is smaller than the pivot, so it should be on the left-hand-side

# %%
# Core Skill 1d: Swap the `Low` and `High` elements

print('Before swap: ', seq)



#print('After swap: ', seq)

# %% [markdown]
# # Core Skill 1 (Summary)
#
# 1. Define all the variables: `start`, `end`, `pivot`, `lo` and `hi`.
# 2. Move `lo` from the first element towards the right until the element value is larger or equal to the `pivot`.
# 3. Move `hi` from the last element towards the left until the element value is smaller than the `pivot`.
# 4. Swap the `lo` and `hi` elements.

# %%
# Core Skill 1 (Summary)

seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5] 
print('Before swap: ', seq)


# Define the variables


# Moving 'Low' to the right


# Moving 'High' to the left


# Swapping the 'Low' and 'High' elements



#print('After swap: ', seq)
# Out:
# After swap:  [1, 3, 4, 2, 8, 9, 0, 6, 7, 5]

# %% [markdown]
# Expected output for Core Skill 1: `[1, 3, 4, 2, 8, 9, 0, 6, 7, 5]`
#
# # Core Skill 2: Repeatedly moving `Low` and `High`
#
# 1. Repeatedly move `lo` and `hi` with the condition `lo` <= `hi`
# 2. Swap the `lo` and `hi` elements only if `lo` <= `hi`

# %%
# Core Skill 2: Repeatedly moving `Low` and `High` 

seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5] 


# Paste your previous codes here:



        
        

print('lo: ', lo)
print('After swap: ', seq)

# %% [markdown]
# Expected output for Core Skill 2: `[1, 3, 4, 2, 0, 9, 8, 6, 7, 5]`
#
# # Core Skill 3: Move the `Pivot` into the correct position
#
# - Swap the `pivot` and the `lo` elements

# %%
# Core Skill 3: Move the `Pivot` into the correct position

seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5] 

# Paste your previous codes here:



        



print('Pivot: ', lo)
print('After swap: ', seq)

# %% [markdown]
# Expected output for Core Skill 3: `[1, 3, 4, 2, 0, 5, 8, 6, 7, 9]`
#
# # Step 1: The `partition()` function
#
# Write program code for the function `partition(seq,start,end)` to return `lo` as the index of the `pivot` after partitioning the sequence `seq` ONCE.

# %%
def partition(seq, start, end):
    pass





seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5] 

print('Pivot :', partition(seq, 0, len(seq)-1))
print('After swap: ', seq)

# %% [markdown]
# ### The right partition
# - [8, 6, 7, 9] from index 6 to 9

# %%
#partition the 'right partition' further

print('Pivot :', partition(seq, _, _))
print('After swap: ', seq)

# %% [markdown]
# - [8, 6, 7] from index 6 to 8

# %%
#partition the 'right partition' further

print('Pivot :', partition(seq, _, _))
print('After swap: ', seq)

# %% [markdown]
# ### The left partition
# - [1, 3, 4, 2, 0] from index 0 to 4

# %%
#partition the 'left partition' further

print('Pivot :', partition(seq, _, _))
print('After swap: ', seq)

# %% [markdown]
# - [3, 4, 2, 1] from index 1 to 4

# %%
#partition the 'left partition' further

print('Pivot :', partition(seq, _, _))
print('After swap: ', seq)

# %% [markdown]
# - [4, 2, 3] from index 2 to 4

# %%
#partition the 'left partition' further

print('Pivot :', partition(seq, _, _))
print('After swap: ', seq)

# %% [markdown]
# # Step 2: The `qsort()` function - partition the sequence recursively
#
# Write program code for the function `qsort(seq,start,end)` to partition the sequence `seq` recursively and returns a sorted `seq`.
#
# - the pivot index: `mid`
# - the left segment: `start` to `mid-1` index
# - the right segment: `mid+1` to `end` index

# %%
# Step 2:

def qsort(seq, start, end):
    pass


        
seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5] 
qsort(seq, 0, len(seq)-1)

# %% [markdown]
# # Step 3: The `quicksort()` wrapper function
#
# Write program code for the function `quicksort(seq)` to:
# - initiate the `start` as the index 0 and `end` as the index of the last element in the sequence `seq`
# - call on the helper function `qsort(seq,start,end)`
# - return the sorted sequence `seq`

# %%
# Step 3:

def quicksort(seq):
    pass

    
    
seq = [1, 3, 7, 2, 8, 9, 0, 6, 4, 5] 

quicksort(seq)
print(seq)

# %% [markdown]
# # Putting them altogether
#
# - the helper function `partition()`
# - the recursive function `qsort()`
# - the wrapper function `quicksort()`

# %%
# Putting it altogether

# %% [markdown]
# ## Generate a list with `n` unique random numbers

# %%
#Run the following code to generate a random sequence with 9 numbers
from random import shuffle

random_seq = list(range(9))
shuffle(random_seq)


print('Random sequence: ', random_seq)

#print('After Quicksort: ', quicksort(random_seq))

# %% [markdown]
# # Modify the `partition()` function to use the first element as the `Pivot`

# %%
# Paste and modify the program code for partition() here:

def partition(seq, start, end): #using the first element as the pivot
    pass


seq1 = [6, 3, 7, 2, 8, 9, 0, 1, 4, 5]

print('Pivot: ', partition(seq1, 0, len(seq1)-1))
print(seq1)

# %%
def qsort(seq, start, end):                    
    if start < end:
        mid = partition(seq, start, end)       #test with first element as pivot
        qsort(seq, start, mid-1)
        qsort(seq, mid+1, end)
    return seq


def quicksort(seq):                            #wrapper function
    qsort(seq, 0, len(seq)-1)
    return seq


from random import shuffle

random_seq = list(range(9))
shuffle(random_seq)

quicksort(random_seq)

# %% [markdown]
#                                        ~ THE END ~
